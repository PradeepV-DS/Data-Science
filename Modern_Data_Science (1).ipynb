# %%
input_Value = '45.6'
type(input_Value)
# Out:
# str

# %%
weight = float(input_Value)
type(weight)
# Out:
# float

# %%
name = input('Enter your Name:   ')
siblings = input('How many siblings do you have:  ')
sib_names = []
for i in range(int(siblings)):
  names = input('Names: ')
  sib_names.append(names)

print('Hello %s, you have %s siblings, %s are your siblings'  % (name, siblings, sib_names))
# Out:
# Enter your Name:   Nani
# How many siblings do you have:  2
# Names: Hemi
# Names: Chintu
# Hello Nani, you have 2 siblings, ['Hemi', 'Chintu'] are your siblings

# %%
for i in range(int(siblings)):
  print(i)
# Out:
# 0
# 1

# %%
print('Hello %s' % name, 'how many siblings do you have %d' % input())
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6a4dc92c1099> in <module>
# ----> 1 print('Hello %s' % name, 'how many siblings do you have %d' % input())
#
# TypeError: %d format: a number is required, not str

# %%
('Output a float number: %10.3f' % (3.5))
# Out:
# 'Output a float number:      3.500'

# %%
def say_hi():
  print('Hi ')

# %%
say_hi()
# Out:
# Hi

# %%
def print_twice(param):
  print(param +' '+ param)

# %%
print_twice('hi')
# Out:
# hi hi

# %%
print_twice(input('Name: '))
# Out:
# Name: hi
# hi hi
